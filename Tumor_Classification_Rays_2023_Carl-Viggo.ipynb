# %% [markdown]
# <a href="https://colab.research.google.com/github/CarlViggo/Carl-Viggo---Rays-2023/blob/main/Tumor_Classification_Rays_2023_Carl-Viggo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Project Pipeline
# The following code classifies images of lung tumors from the Kaggle Data Science Bowl 2017 data set.
#
# **Part 1** \\
# Random Forests, Decision Tree and K-Nearest Neighbors are initially compared to one another. The best model is chosen and evaluated furter.
#
# **Part 2** \\
# Three different convoluitional neural network architectures, of increasing complexity, are compared to one another, LeNet, AlexNet and VGG16 with transfer learning.
#
# /Carl Viggo Nilsson Gravenhorst-Lövenstierne

# %% [markdown]
# **The following definitions are used in the code**
# \
# \
# 1 - Malignant \\
# 0 - Benign
# \
# \
# Class1 - benign \\
# Class2 - malignant
# \
# \
# Train size = 907 \\
# Validation size = 390

# %% [markdown]
# ---

# %%
from google.colab import drive
drive.mount('/content/drive')
# !ln -s "/content/drive/My Drive/Rays/Projects/" /gdrive
# Out:
# Mounted at /content/drive

# %%
import os
import cv2
import numpy as np
from random import shuffle
from skimage.io import imread
import matplotlib.pyplot as plt
from skimage.transform import resize

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Activation, Dropout, ZeroPadding2D
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization, Convolution2D
from tensorflow.keras.optimizers import Adam, RMSprop, SGD
from keras.preprocessing.image import ImageDataGenerator
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.models import Model
from tensorflow.keras import applications
from keras.layers import GlobalAveragePooling2D

# %%
#Matches the file name with its corresponding class
def gen_labels(im_name, data_path, pat1, pat2):
    '''

    Parameters
    ----------
    im_name : Str
        The image file name.

    Returns
    -------
    Label : Numpy array
        Class label of the filename name based on its pattern.
    '''
    if "C1" in data_path:
        label = np.array([0])
    elif "C2" in data_path:
        label = np.array([1])
    return label

#Creates a nested list with the following structure: [(file_name, label), ...]
def get_data(data_path, data_list, img_h, img_w):
    """

    Parameters
    ----------
    train_data_path : Str
        Path to the data directory
    train_list : List
        A list containing the name of the images.
    img_h : Int
        image height to be resized to.
    img_w : Int
        image width to be resized to.
    """
    img_labels = []
    for item in enumerate(data_list):
        img = imread(os.path.join(data_path, item[1]), as_gray = False) # "as_grey"
        #img = cv2.imread(os.path.join(data_path, item[1]))
        img = resize(img, (img_h, img_w), anti_aliasing = True).astype('float32')
        img_labels.append([np.array(img), gen_labels(item[1], data_path,  'AFF', 'NFF')])

        if item[0] % 100 == 0:
             print('Reading: {0}/{1}  of train images'.format(item[0], len(data_list)))

    #Shuffles the list for generalization purposes
    shuffle(img_labels)
    return img_labels

#Unfolds the images and converts them to compatible arrays.
def get_data_arrays(nested_list, img_h, img_w):
    """
    Parameters
    ----------
    nested_list : nested list
        nested list of image arrays with corresponding class labels.
    img_h : Int
        Image height.
    img_w : Int
        Image width.

    Returns
    -------
    img_arrays : Numpy array
        4D Array with the size of (n_data,img_h,img_w, 1)
    label_arrays : Numpy array
        1D array with the size (n_data).

    """
    img_arrays = np.zeros((len(nested_list), img_h, img_w), dtype = np.float32)
    label_arrays = np.zeros((len(nested_list)), dtype = np.int32)
    for ind in range(len(nested_list)):
        img_arrays[ind] = nested_list[ind][0]
        label_arrays[ind] = nested_list[ind][1]
    img_arrays = np.expand_dims(img_arrays, axis =3)
    return img_arrays, label_arrays

#Returns the training and the testing data
def get_train_test_arrays(train_data_path, test_data_path, train_list,
                          test_list, img_h, img_w):

    """
    Get the directory to the train and test sets, the files names and
    the size of the image and return the image and label arrays for
    train and test sets.
    """

    train_data = get_data(train_data_path, train_list, img_h, img_w)
    test_data = get_data(test_data_path, test_list, img_h, img_w)

    train_img, train_label =  get_data_arrays(train_data, img_h, img_w)
    test_img, test_label = get_data_arrays(test_data, img_h, img_w)
    del(train_data)
    del(test_data)
    return train_img, test_img, train_label, test_label

# %%
#Define input arguments for get_train_test_arrays

c1_train_data_path = "/gdrive/Data/Lung_2D/images/class1/C1_train/"
c1_test_data_path = "/gdrive/Data/Lung_2D/images/class1/C1_test/"

c2_train_data_path = "/gdrive/Data/Lung_2D/images/class2/C2_train/"
c2_test_data_path = "/gdrive/Data/Lung_2D/images/class2/C2_test/"

#Creates lists containing the file names for the different classes
c1_train_list = os.listdir(c1_train_data_path)
c1_val_list = os.listdir(c1_test_data_path)

c2_train_list = os.listdir(c2_train_data_path)
c2_val_list = os.listdir(c2_test_data_path)

# %%
#Defines the image dimensions
img_h = 224
img_w = 224

# %%
#Retrieves training and testing data for C1 class (benign)
c1_x_train, c1_x_test, c1_y_train, c1_y_test = get_train_test_arrays(c1_train_data_path, c1_test_data_path, c1_train_list, c1_val_list, img_h, img_w)
# Out:
# Reading: 0/614  of train images
# Reading: 100/614  of train images
# Reading: 200/614  of train images
# Reading: 300/614  of train images
# Reading: 400/614  of train images
# Reading: 500/614  of train images
# Reading: 600/614  of train images
# Reading: 0/254  of train images
# Reading: 100/254  of train images
# Reading: 200/254  of train images

# %%
#Retrieves training and testing data for C2 class (malignant)
c2_x_train, c2_x_test, c2_y_train, c2_y_test = get_train_test_arrays(
        c2_train_data_path, c2_test_data_path,
        c2_train_list, c2_val_list, img_h, img_w)
# Out:
# Reading: 0/293  of train images
# Reading: 100/293  of train images
# Reading: 200/293  of train images
# Reading: 0/120  of train images
# Reading: 100/120  of train images

# %%
#Combines the C1 and the C2 testing and training data to create the final training and testing data
x_train = np.concatenate((c1_x_train, c2_x_train))
y_train = np.concatenate((c1_y_train, c2_y_train))
x_val = np.concatenate((c1_x_test, c2_x_test))
y_val = np.concatenate((c1_y_test, c2_y_test))

x_train.shape
# Out:
# (907, 224, 224, 1)

# %% [markdown]
# #Vizualization

# %%
#Verify matching between image and label.
plt.imshow(x_train[800])
print(y_train[800])
# Out:
# 1

# %%
#For vizualisation purposes. Vizualizez a selection of images from the both classes and their corresponding labels

import matplotlib.pyplot as plt

fig, axs = plt.subplots(2, 8, figsize=(16, 4))

# Array of titles
titles = y_train

# Iterate over each subplot and title
for i in range(2):
    for j in range(8):
        # Load and display the images
        axs[i, j].imshow(x_train[i*8 + j], cmap='gray')
        axs[i, j].set_title(titles[i*8 + j])
        axs[i, j].axis('off')

# Adjust the spacing between subplots
plt.tight_layout()

fig2, axs2 = plt.subplots(2, 8, figsize=(16, 4))

# Starting index
start_index = 890

# Repeat for second class
for k in range(2):
    for h in range(8):
        index = start_index + k*8 + h

        axs2[k, h].imshow(x_train[index], cmap='gray')

        axs2[k, h].set_title(y_train[index])

        axs2[k, h].axis('off')

plt.tight_layout()

plt.show()

# %% [markdown]
# #Plotting Function

# %% [markdown]
# #Model Architectures

# %%
#Generates two subplots of learning curves
def plotting(model_name, directory_path, save, from_val, from_acc):

  model_std_loss = np.std(model_name.history["val_loss"][from_val:])
  model_mean_loss = np.mean(model_name.history["val_loss"][from_val:])
  model_boundary_high_loss = model_mean_loss + model_std_loss
  model_boundary_low_loss = model_mean_loss - model_std_loss

  model_std_acc = np.std(model_name.history["val_binary_accuracy"][from_acc:])
  model_mean_acc = np.mean(model_name.history["val_binary_accuracy"][from_acc:])
  model_boundary_high_acc = model_mean_acc + model_std_acc
  model_boundary_low_acc = model_mean_acc - model_std_acc

  fig, axes = plt.subplots(1, 2, figsize=(10, 4))

  # Plot Loss Value
  axes[1].axhline(model_mean_loss, color='red', linestyle='--', label='mean val loss')
  axes[1].axhline(model_boundary_high_loss, color='green', linestyle='--', label='decision boundary (+std_dev)')
  axes[1].axhline(model_boundary_low_loss, color='blue', linestyle='--', label='decision boundary (-std_dev)')


  axes[1].plot(model_name.history["loss"], label="loss")
  axes[1].plot(model_name.history["val_loss"], label="val loss")
  axes[1].plot(np.argmin(model_name.history["val_loss"]),
              np.min(model_name.history["val_loss"]),
              marker="x", color="r", label="best model")
  axes[1].set_xlabel("Epochs")
  axes[1].set_ylabel("Loss Value")
  axes[1].legend(frameon=False)

  # Plot Validation Accuracy
  axes[0].axhline(model_mean_acc, color='red', linestyle='--', label='mean val accuracy')
  axes[0].axhline(model_boundary_high_acc, color='green', linestyle='--', label='decision boundary (+std_dev)')
  axes[0].axhline(model_boundary_low_acc, color='blue', linestyle='--', label='decision boundary (-std_dev)')
  axes[0].plot(model_name.history["binary_accuracy"], label="accuracy")
  axes[0].plot(model_name.history["val_binary_accuracy"], label="val accuracy")
  axes[0].plot(np.argmax(model_name.history["val_binary_accuracy"]),
          np.max(model_name.history["val_binary_accuracy"]),
          marker="x", color="r", label="best model")
  axes[0].set_xlabel("Epochs")
  axes[0].set_ylabel("Accuracy")
  axes[0].legend(loc="lower right", frameon=False)

  plt.tight_layout()
  if save == True:
    plt.savefig(directory_path, dpi=300)

  plt.show()
  print(model_std_loss)
  print(model_std_acc)
  print(model_mean_loss)
  print(model_mean_acc)
  return

# %%
#LeNet Architecture
def LeNet(img_ch, img_width, img_height):
    model = Sequential()
    model.add(Conv2D(n_base, kernel_size = (3, 3), activation='relu',
                     strides=1, padding='same',
                     input_shape = (img_width, img_height, img_ch))) #base determines the number of filters that should be applied.
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(n_base*2, kernel_size = (3, 3), activation='relu',
                     strides=1, padding='same'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Flatten()) #Flatten before entering the dense layer.
    model.add(Dense(n_base*2, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.summary()

    return model

# %%
# AlexNet Architecture
def AlexNet(img_ch, img_width, img_height):

    model = Sequential()

    model.add(Conv2D(filters=n_base, input_shape=(img_width, img_height, img_ch),
                     kernel_size=(3,3), strides=(1,1), padding='same'))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(filters=n_base*2, kernel_size=(3,3), strides=(1,1), padding='same'))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(filters=n_base*4, kernel_size=(3,3), strides=(1,1), padding='same'))
    model.add(Activation('relu'))

    model.add(Conv2D(filters=n_base*4, kernel_size=(3,3), strides=(1,1), padding='same'))
    model.add(Activation('relu'))

    model.add(Conv2D(filters=n_base*2, kernel_size=(3,3), strides=(1,1), padding='same'))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Flatten())
    model.add(Dense(128))
    model.add(Activation('relu'))
    model.add(Dropout(0.4))

    model.add(Dense(64))
    model.add(Activation('relu'))
    model.add(Dropout(0.4))

    model.add(Dense(1))
    model.add(Activation('sigmoid'))

    model.summary()
    return model

# %%
#VGG16 Architecture
def VGG_16(weights_path=None):
    model = Sequential()
    model.add(ZeroPadding2D((1,1),input_shape=(3,224,224)))
    model.add(Convolution2D(64, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(64, 3, 3, activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))

    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(128, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(128, 3, 3, activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))

    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(256, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(256, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(256, 3, 3, activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))

    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))

    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))

    model.add(Flatten())
    model.add(Dense(4096, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(4096, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(1000, activation='softmax'))
    model.summary()
    return model

# %% [markdown]
# ---

# %%
#Verify shapes
print(x_train.shape)
print(x_train[0].shape)
# Out:
# (907, 224, 224, 1)
# (224, 224, 1)

# %%
#Define hyperparameters
img_ch, img_width, img_height = 1, 224, 224
n_epochs = 50
batch_s = 3
n_base = 4
learn_rate = 1e-5

# %%
#For the VGG16 model, the shape must be (244,244,3). The current shape is (244,244,1). The following code stacks three identical images on top of another to fulfill the criteria.
x_trainRGB = np.array([np.concatenate([gray_image] * 3, axis=2) for gray_image in x_train])
x_valRGB = np.array([np.concatenate([gray_image] * 3, axis=2) for gray_image in x_val])

# %%
#Instantiates the pre-trained VGG16 network
VGG16 = applications.VGG16(include_top=False, weights='imagenet')

#Makes sure the model won't be trained
for layer in VGG16.layers:
    layer.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step

# %%
#Generates feature maps from the VGG16 model
x_train_predict = VGG16.predict(x_trainRGB)
x_val_predict = VGG16.predict(x_valRGB)
# Out:
# 29/29 [==============================] - 584s 20s/step
# 12/12 [==============================] - 233s 19s/step

# %%
#Defines the trainable neural network connected to the pre-trained VGG16 model
model_1 = Sequential()
model_1.add(Flatten(input_shape=x_train_predict.shape[1:]))
model_1.add(Dense(512, activation='relu'))
model_1.add(Dropout(0.5))
model_1.add(Dense(256, activation='relu'))
model_1.add(Dropout(0.5))
model_1.add(Dense(32, activation='relu'))
model_1.add(Dropout(0.5))
model_1.add(Dense(1, activation='sigmoid'))
model_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 512)               12845568
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 32)                8224
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 12,985,153
# Trainable params: 12,985,153
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_1.compile(optimizer=Adam(learning_rate = learn_rate),loss='binary_crossentropy', metrics=['accuracy'])

# %%
#Fit the neural network added on top of the VGG16 model
VGG16 = model_1.fit(x_train_predict, y_train,
          epochs=n_epochs,
          batch_size=batch_s,
          validation_data=(x_val_predict, y_val))
# Out:
# Epoch 1/50
# 303/303 [==============================] - 58s 190ms/step - loss: 0.6957 - accuracy: 0.5711 - val_loss: 0.6293 - val_accuracy: 0.6791
# Epoch 2/50
# 303/303 [==============================] - 59s 194ms/step - loss: 0.6608 - accuracy: 0.6185 - val_loss: 0.5994 - val_accuracy: 0.6791
# Epoch 3/50
# 303/303 [==============================] - 59s 196ms/step - loss: 0.6319 - accuracy: 0.6648 - val_loss: 0.5950 - val_accuracy: 0.6791
# Epoch 4/50
# 303/303 [==============================] - 59s 193ms/step - loss: 0.6585 - accuracy: 0.6284 - val_loss: 0.5891 - val_accuracy: 0.6791
# Epoch 5/50
# 303/303 [==============================] - 59s 194ms/step - loss: 0.6402 - accuracy: 0.6494 - val_loss: 0.5980 - val_accuracy: 0.6898
# Epoch 6/50
# 303/303 [==============================] - 57s 189ms/step - loss: 0.6337 - accuracy: 0.6284 - val_loss: 0.5791 - val_accuracy: 0.7059
# Epoch 7/50
# 303/303 [==============================] - 57s 190ms/step - loss: 0.6126 - accuracy: 0.6803 - val_loss: 0.5738 - val_accuracy: 0.7032
# Epoch 8/50
# 303/303 [==============================] - 60s 197ms/step - loss: 0.6268 - accuracy: 0.6681 - val_loss: 0.5766 - val_accuracy: 0.7273
# Epoch 9/50
# 303/303 [==============================] - 70s 232ms/step - loss: 0.6113 - accuracy: 0.6759 - val_loss: 0.5630 - val_accuracy: 0.7273
# Epoch 10/50
# 303/303 [==============================] - 60s 199ms/step - loss: 0.6117 - accuracy: 0.6759 - val_loss: 0.5614 - val_accuracy: 0.7273
# Epoch 11/50
# 303/303 [==============================] - 62s 204ms/step - loss: 0.6081 - accuracy: 0.6714 - val_loss: 0.5596 - val_accuracy: 0.7299
# Epoch 12/50
# 303/303 [==============================] - 60s 198ms/step - loss: 0.6092 - accuracy: 0.6803 - val_loss: 0.5654 - val_accuracy: 0.7540
# Epoch 13/50
# 303/303 [==============================] - 62s 204ms/step - loss: 0.6098 - accuracy: 0.6836 - val_loss: 0.5743 - val_accuracy: 0.7620
# Epoch 14/50
# 303/303 [==============================] - 58s 192ms/step - loss: 0.6039 - accuracy: 0.6869 - val_loss: 0.5527 - val_accuracy: 0.7594
# Epoch 15/50
# 303/303 [==============================] - 59s 196ms/step - loss: 0.5860 - accuracy: 0.6990 - val_loss: 0.5475 - val_accuracy: 0.7487
# Epoch 16/50
# 303/303 [==============================] - 60s 198ms/step - loss: 0.5773 - accuracy: 0.7166 - val_loss: 0.5553 - val_accuracy: 0.7513
# Epoch 17/50
# 303/303 [==============================] - 60s 197ms/step - loss: 0.5822 - accuracy: 0.7178 - val_loss: 0.5579 - val_accuracy: 0.7487
# Epoch 18/50
# 303/303 [==============================] - 58s 192ms/step - loss: 0.5711 - accuracy: 0.7178 - val_loss: 0.5416 - val_accuracy: 0.7513
# Epoch 19/50
# 303/303 [==============================] - 73s 242ms/step - loss: 0.5641 - accuracy: 0.7288 - val_loss: 0.5429 - val_accuracy: 0.7567
# Epoch 20/50
# 303/303 [==============================] - 60s 198ms/step - loss: 0.5804 - accuracy: 0.7034 - val_loss: 0.5391 - val_accuracy: 0.7487
# Epoch 21/50
# 303/303 [==============================] - 59s 195ms/step - loss: 0.5729 - accuracy: 0.7155 - val_loss: 0.5479 - val_accuracy: 0.7219
# Epoch 22/50
# 303/303 [==============================] - 62s 203ms/step - loss: 0.5600 - accuracy: 0.7222 - val_loss: 0.5409 - val_accuracy: 0.7513
# Epoch 23/50
# 303/303 [==============================] - 60s 199ms/step - loss: 0.5566 - accuracy: 0.7277 - val_loss: 0.5345 - val_accuracy: 0.7567
# Epoch 24/50
# 303/303 [==============================] - 60s 199ms/step - loss: 0.5640 - accuracy: 0.7321 - val_loss: 0.5361 - val_accuracy: 0.7647
# Epoch 25/50
# 303/303 [==============================] - 60s 199ms/step - loss: 0.5581 - accuracy: 0.7365 - val_loss: 0.5322 - val_accuracy: 0.7620
# Epoch 26/50
# 303/303 [==============================] - 60s 197ms/step - loss: 0.5393 - accuracy: 0.7607 - val_loss: 0.5285 - val_accuracy: 0.7594
# Epoch 27/50
# 303/303 [==============================] - 62s 204ms/step - loss: 0.5616 - accuracy: 0.7387 - val_loss: 0.5284 - val_accuracy: 0.7701
# Epoch 28/50
# 303/303 [==============================] - 59s 195ms/step - loss: 0.5462 - accuracy: 0.7343 - val_loss: 0.5303 - val_accuracy: 0.7326
# Epoch 29/50
# 303/303 [==============================] - 70s 232ms/step - loss: 0.5454 - accuracy: 0.7343 - val_loss: 0.5238 - val_accuracy: 0.7674
# Epoch 30/50
# 303/303 [==============================] - 62s 205ms/step - loss: 0.5487 - accuracy: 0.7431 - val_loss: 0.5303 - val_accuracy: 0.7567
# Epoch 31/50
# 303/303 [==============================] - 60s 199ms/step - loss: 0.5443 - accuracy: 0.7420 - val_loss: 0.5246 - val_accuracy: 0.7513
# Epoch 32/50
# 303/303 [==============================] - 61s 201ms/step - loss: 0.5388 - accuracy: 0.7453 - val_loss: 0.5217 - val_accuracy: 0.7540
# Epoch 33/50
# 303/303 [==============================] - 62s 204ms/step - loss: 0.5382 - accuracy: 0.7574 - val_loss: 0.5311 - val_accuracy: 0.7406
# Epoch 34/50
# 303/303 [==============================] - 59s 194ms/step - loss: 0.5413 - accuracy: 0.7475 - val_loss: 0.5240 - val_accuracy: 0.7647
# Epoch 35/50
# 303/303 [==============================] - 60s 198ms/step - loss: 0.5195 - accuracy: 0.7596 - val_loss: 0.5235 - val_accuracy: 0.7406
# Epoch 36/50
# 303/303 [==============================] - 61s 200ms/step - loss: 0.5196 - accuracy: 0.7541 - val_loss: 0.5207 - val_accuracy: 0.7487
# Epoch 37/50
# 303/303 [==============================] - 59s 195ms/step - loss: 0.5320 - accuracy: 0.7530 - val_loss: 0.5278 - val_accuracy: 0.7594
# Epoch 38/50
# 303/303 [==============================] - 60s 199ms/step - loss: 0.5099 - accuracy: 0.7850 - val_loss: 0.5211 - val_accuracy: 0.7460
# Epoch 39/50
# 303/303 [==============================] - 79s 260ms/step - loss: 0.5063 - accuracy: 0.7707 - val_loss: 0.5215 - val_accuracy: 0.7433
# Epoch 40/50
# 303/303 [==============================] - 59s 195ms/step - loss: 0.4942 - accuracy: 0.7784 - val_loss: 0.5199 - val_accuracy: 0.7567
# Epoch 41/50
# 303/303 [==============================] - 61s 200ms/step - loss: 0.5144 - accuracy: 0.7607 - val_loss: 0.5203 - val_accuracy: 0.7353
# Epoch 42/50
# 303/303 [==============================] - 59s 195ms/step - loss: 0.4917 - accuracy: 0.7751 - val_loss: 0.5199 - val_accuracy: 0.7433
# Epoch 43/50
# 303/303 [==============================] - 59s 194ms/step - loss: 0.5025 - accuracy: 0.7806 - val_loss: 0.5228 - val_accuracy: 0.7647
# Epoch 44/50
# 303/303 [==============================] - 61s 203ms/step - loss: 0.5014 - accuracy: 0.7762 - val_loss: 0.5234 - val_accuracy: 0.7567
# Epoch 45/50
# 303/303 [==============================] - 60s 199ms/step - loss: 0.4931 - accuracy: 0.7861 - val_loss: 0.5215 - val_accuracy: 0.7487
# Epoch 46/50
# 303/303 [==============================] - 61s 203ms/step - loss: 0.4879 - accuracy: 0.7751 - val_loss: 0.5291 - val_accuracy: 0.7513
# Epoch 47/50
# 303/303 [==============================] - 62s 206ms/step - loss: 0.5032 - accuracy: 0.7773 - val_loss: 0.5264 - val_accuracy: 0.7513
# Epoch 48/50
# 303/303 [==============================] - 59s 194ms/step - loss: 0.4834 - accuracy: 0.7872 - val_loss: 0.5278 - val_accuracy: 0.7567
# Epoch 49/50
# 303/303 [==============================] - 69s 228ms/step - loss: 0.4856 - accuracy: 0.7762 - val_loss: 0.5256 - val_accuracy: 0.7513
# Epoch 50/50
# 303/303 [==============================] - 60s 196ms/step - loss: 0.4826 - accuracy: 0.7938 - val_loss: 0.5230 - val_accuracy: 0.7513

# %%
model_file_path = '/content/drive/My Drive/Rays/Projects/Saved_Models/VGG16.h5'

# Save the model
model_1.save(model_file_path)

# %%
#statistics.
VGG16_std_loss = np.std(VGG16.history["val_loss"][15:])
VGG16_mean_loss = np.mean(VGG16.history["val_loss"][15:])
VGG16_boundary_high_loss = VGG16_mean_loss + VGG16_std_loss
VGG16_boundary_low_loss = VGG16_mean_loss - VGG16_std_loss

VGG16_std_acc = np.std(VGG16.history["accuracy"][15:])
VGG16_mean_acc = np.mean(VGG16.history["accuracy"][15:])
VGG16_boundary_high_acc = VGG16_mean_acc + VGG16_std_acc
VGG16_boundary_low_acc = VGG16_mean_acc - VGG16_std_acc

print(VGG16_std_loss)
print(VGG16_std_acc)
print(VGG16_mean_loss)
print(VGG16_mean_acc)
# Out:
# 0.009736179081823258
# 0.024620301944975588
# 0.5298611760139466
# 0.7517404351915632

# %%
#Plot the learning curves from the VGG16 model
import matplotlib.pyplot as plt
import numpy as np


fig, axes = plt.subplots(1, 2, figsize=(10, 4))

# Plot for Loss Value

# Plotting
axes[1].axhline(VGG16_mean_loss, color='red', linestyle='--', label='mean val loss')
axes[1].axhline(VGG16_boundary_high_loss, color='green', linestyle='--', label='decision boundary (+std_dev)')
axes[1].axhline(VGG16_boundary_low_loss, color='blue', linestyle='--', label='decision boundary (-std_dev)')

axes[1].plot(VGG16.history["loss"], label="loss")
axes[1].plot(VGG16.history["val_loss"], label="val loss")
axes[1].plot(np.argmin(VGG16.history["val_loss"]),
             np.min(VGG16.history["val_loss"]),
             marker="x", color="r", label="best model")
axes[1].set_xlabel("Epochs")
axes[1].set_ylabel("Loss Value")
axes[1].legend(frameon=False)


# Plot for Validation Accuracy
axes[0].axhline(VGG16_mean_acc, color='red', linestyle='--', label='mean val accuracy')
axes[0].axhline(VGG16_boundary_high_acc, color='green', linestyle='--', label='decision boundary (+std_dev)')
axes[0].axhline(VGG16_boundary_low_acc, color='blue', linestyle='--', label='decision boundary (-std_dev)')
axes[0].plot(VGG16.history["accuracy"], label="accuracy")
axes[0].plot(VGG16.history["val_accuracy"], label="val accuracy")
axes[0].plot(np.argmax(VGG16.history["val_accuracy"]),
             np.max(VGG16.history["val_accuracy"]),
             marker="x", color="r", label="best model")
axes[0].set_xlabel("Epochs")
axes[0].set_ylabel("Accuracy")
axes[0].legend(frameon=False)

plt.tight_layout()

plt.savefig("/content/drive/My Drive/Rays/Images_Graphs/Statistical/VGG16_50epochs_stats.png", dpi=300)

plt.show()
print()

# %% [markdown]
# #AlexNet

# %%
#Create train & test data for the AlexNet and the LeNet
x_train = np.concatenate((c1_x_train, c2_x_train))
y_train = np.concatenate((c1_y_train, c2_y_train))
x_val = np.concatenate((c1_x_test, c2_x_test))
y_val = np.concatenate((c1_y_test, c2_y_test))

# %%
#Define HyperParameters for AlexNet and LeNet
img_ch, img_width, img_height = 1, 224, 224
n_epochs = 50
batch_s = 3
n_base = 4
learn_rate = 1e-5

# %%
#Instantiate the AlexNet model
alex = AlexNet(img_ch, img_width, img_height)

alex.compile(loss='binary_crossentropy',
              optimizer=Adam(learning_rate=learn_rate),
              metrics=['binary_accuracy'])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 4)       40
#
#  activation (Activation)     (None, 224, 224, 4)       0
#
#  max_pooling2d (MaxPooling2D  (None, 112, 112, 4)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 8)       296
#
#  activation_1 (Activation)   (None, 112, 112, 8)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 56, 56, 8)        0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 16)        1168
#
#  activation_2 (Activation)   (None, 56, 56, 16)        0
#
#  conv2d_3 (Conv2D)           (None, 56, 56, 16)        2320
#
#  activation_3 (Activation)   (None, 56, 56, 16)        0
#
#  conv2d_4 (Conv2D)           (None, 56, 56, 8)         1160
#
#  activation_4 (Activation)   (None, 56, 56, 8)         0
#
#  max_pooling2d_2 (MaxPooling  (None, 28, 28, 8)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 6272)              0
#
#  dense_4 (Dense)             (None, 128)               802944
#
#  activation_5 (Activation)   (None, 128)               0
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 64)                8256
#
#  activation_6 (Activation)   (None, 64)                0
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_6 (Dense)             (None, 1)                 65
#
#  activation_7 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 816,249
# Trainable params: 816,249
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Train the AlexNet model
alex_hist = alex.fit(x_train, y_train, batch_size = batch_s,
                  validation_data = (x_val, y_val),
                  epochs = n_epochs, verbose=1)
# Out:
# Epoch 1/50
# 303/303 [==============================] - 41s 129ms/step - loss: 0.6817 - binary_accuracy: 0.6439 - val_loss: 0.6676 - val_binary_accuracy: 0.6791
# Epoch 2/50
# 303/303 [==============================] - 36s 120ms/step - loss: 0.6551 - binary_accuracy: 0.6759 - val_loss: 0.6473 - val_binary_accuracy: 0.6791
# Epoch 3/50
# 303/303 [==============================] - 41s 135ms/step - loss: 0.6450 - binary_accuracy: 0.6770 - val_loss: 0.6431 - val_binary_accuracy: 0.6791
# Epoch 4/50
# 303/303 [==============================] - 36s 120ms/step - loss: 0.6411 - binary_accuracy: 0.6770 - val_loss: 0.6402 - val_binary_accuracy: 0.6791
# Epoch 5/50
# 303/303 [==============================] - 40s 131ms/step - loss: 0.6387 - binary_accuracy: 0.6770 - val_loss: 0.6363 - val_binary_accuracy: 0.6791
# Epoch 6/50
# 303/303 [==============================] - 38s 126ms/step - loss: 0.6318 - binary_accuracy: 0.6770 - val_loss: 0.6317 - val_binary_accuracy: 0.6791
# Epoch 7/50
# 303/303 [==============================] - 39s 130ms/step - loss: 0.6315 - binary_accuracy: 0.6725 - val_loss: 0.6263 - val_binary_accuracy: 0.6791
# Epoch 8/50
# 303/303 [==============================] - 46s 153ms/step - loss: 0.6127 - binary_accuracy: 0.6781 - val_loss: 0.6204 - val_binary_accuracy: 0.6791
# Epoch 9/50
# 303/303 [==============================] - 41s 134ms/step - loss: 0.6215 - binary_accuracy: 0.6770 - val_loss: 0.6145 - val_binary_accuracy: 0.6791
# Epoch 10/50
# 303/303 [==============================] - 39s 127ms/step - loss: 0.6190 - binary_accuracy: 0.6770 - val_loss: 0.6090 - val_binary_accuracy: 0.6791
# Epoch 11/50
# 303/303 [==============================] - 39s 130ms/step - loss: 0.6047 - binary_accuracy: 0.6759 - val_loss: 0.6034 - val_binary_accuracy: 0.6791
# Epoch 12/50
# 303/303 [==============================] - 41s 134ms/step - loss: 0.6009 - binary_accuracy: 0.6781 - val_loss: 0.6006 - val_binary_accuracy: 0.6791
# Epoch 13/50
# 303/303 [==============================] - 38s 125ms/step - loss: 0.6030 - binary_accuracy: 0.6759 - val_loss: 0.5954 - val_binary_accuracy: 0.6845
# Epoch 14/50
# 303/303 [==============================] - 42s 137ms/step - loss: 0.6079 - binary_accuracy: 0.6836 - val_loss: 0.5898 - val_binary_accuracy: 0.6872
# Epoch 15/50
# 303/303 [==============================] - 38s 127ms/step - loss: 0.5934 - binary_accuracy: 0.6869 - val_loss: 0.5850 - val_binary_accuracy: 0.7059
# Epoch 16/50
# 303/303 [==============================] - 40s 133ms/step - loss: 0.5940 - binary_accuracy: 0.6902 - val_loss: 0.5836 - val_binary_accuracy: 0.7005
# Epoch 17/50
# 303/303 [==============================] - 43s 143ms/step - loss: 0.5842 - binary_accuracy: 0.6935 - val_loss: 0.5790 - val_binary_accuracy: 0.7112
# Epoch 18/50
# 303/303 [==============================] - 45s 148ms/step - loss: 0.5875 - binary_accuracy: 0.6924 - val_loss: 0.5761 - val_binary_accuracy: 0.7112
# Epoch 19/50
# 303/303 [==============================] - 37s 123ms/step - loss: 0.5796 - binary_accuracy: 0.7100 - val_loss: 0.5766 - val_binary_accuracy: 0.7112
# Epoch 20/50
# 303/303 [==============================] - 40s 131ms/step - loss: 0.5812 - binary_accuracy: 0.7001 - val_loss: 0.5711 - val_binary_accuracy: 0.7139
# Epoch 21/50
# 303/303 [==============================] - 38s 126ms/step - loss: 0.5806 - binary_accuracy: 0.7045 - val_loss: 0.5708 - val_binary_accuracy: 0.7139
# Epoch 22/50
# 303/303 [==============================] - 41s 134ms/step - loss: 0.5751 - binary_accuracy: 0.7133 - val_loss: 0.5687 - val_binary_accuracy: 0.7166
# Epoch 23/50
# 303/303 [==============================] - 44s 144ms/step - loss: 0.5787 - binary_accuracy: 0.6979 - val_loss: 0.5721 - val_binary_accuracy: 0.7112
# Epoch 24/50
# 303/303 [==============================] - 39s 129ms/step - loss: 0.5740 - binary_accuracy: 0.7111 - val_loss: 0.5687 - val_binary_accuracy: 0.7166
# Epoch 25/50
# 303/303 [==============================] - 37s 122ms/step - loss: 0.5742 - binary_accuracy: 0.7056 - val_loss: 0.5635 - val_binary_accuracy: 0.7112
# Epoch 26/50
# 303/303 [==============================] - 44s 144ms/step - loss: 0.5729 - binary_accuracy: 0.7056 - val_loss: 0.5611 - val_binary_accuracy: 0.7112
# Epoch 27/50
# 303/303 [==============================] - 46s 151ms/step - loss: 0.5633 - binary_accuracy: 0.7200 - val_loss: 0.5598 - val_binary_accuracy: 0.7139
# Epoch 28/50
# 303/303 [==============================] - 44s 145ms/step - loss: 0.5711 - binary_accuracy: 0.7100 - val_loss: 0.5588 - val_binary_accuracy: 0.7112
# Epoch 29/50
# 303/303 [==============================] - 38s 126ms/step - loss: 0.5647 - binary_accuracy: 0.7144 - val_loss: 0.5583 - val_binary_accuracy: 0.7086
# Epoch 30/50
# 303/303 [==============================] - 40s 130ms/step - loss: 0.5654 - binary_accuracy: 0.7100 - val_loss: 0.5610 - val_binary_accuracy: 0.7166
# Epoch 31/50
# 303/303 [==============================] - 44s 145ms/step - loss: 0.5663 - binary_accuracy: 0.7299 - val_loss: 0.5591 - val_binary_accuracy: 0.7139
# Epoch 32/50
# 303/303 [==============================] - 39s 130ms/step - loss: 0.5653 - binary_accuracy: 0.7089 - val_loss: 0.5561 - val_binary_accuracy: 0.7166
# Epoch 33/50
# 303/303 [==============================] - 41s 135ms/step - loss: 0.5611 - binary_accuracy: 0.7155 - val_loss: 0.5553 - val_binary_accuracy: 0.7193
# Epoch 34/50
# 303/303 [==============================] - 40s 131ms/step - loss: 0.5581 - binary_accuracy: 0.7089 - val_loss: 0.5547 - val_binary_accuracy: 0.7166
# Epoch 35/50
# 303/303 [==============================] - 40s 131ms/step - loss: 0.5617 - binary_accuracy: 0.7155 - val_loss: 0.5584 - val_binary_accuracy: 0.7112
# Epoch 36/50
# 303/303 [==============================] - 38s 127ms/step - loss: 0.5463 - binary_accuracy: 0.7310 - val_loss: 0.5621 - val_binary_accuracy: 0.7139
# Epoch 37/50
# 303/303 [==============================] - 46s 152ms/step - loss: 0.5542 - binary_accuracy: 0.7299 - val_loss: 0.5526 - val_binary_accuracy: 0.7112
# Epoch 38/50
# 303/303 [==============================] - 39s 127ms/step - loss: 0.5627 - binary_accuracy: 0.7200 - val_loss: 0.5536 - val_binary_accuracy: 0.7112
# Epoch 39/50
# 303/303 [==============================] - 43s 143ms/step - loss: 0.5551 - binary_accuracy: 0.7189 - val_loss: 0.5541 - val_binary_accuracy: 0.7112
# Epoch 40/50
# 303/303 [==============================] - 38s 127ms/step - loss: 0.5483 - binary_accuracy: 0.7343 - val_loss: 0.5511 - val_binary_accuracy: 0.7139
# Epoch 41/50
# 303/303 [==============================] - 39s 130ms/step - loss: 0.5521 - binary_accuracy: 0.7144 - val_loss: 0.5505 - val_binary_accuracy: 0.7193
# Epoch 42/50
# 303/303 [==============================] - 41s 136ms/step - loss: 0.5503 - binary_accuracy: 0.7288 - val_loss: 0.5559 - val_binary_accuracy: 0.7112
# Epoch 43/50
# 303/303 [==============================] - 38s 126ms/step - loss: 0.5448 - binary_accuracy: 0.7133 - val_loss: 0.5510 - val_binary_accuracy: 0.7193
# Epoch 44/50
# 303/303 [==============================] - 39s 130ms/step - loss: 0.5445 - binary_accuracy: 0.7255 - val_loss: 0.5492 - val_binary_accuracy: 0.7112
# Epoch 45/50
# 303/303 [==============================] - 44s 144ms/step - loss: 0.5574 - binary_accuracy: 0.7365 - val_loss: 0.5481 - val_binary_accuracy: 0.7166
# Epoch 46/50
# 303/303 [==============================] - 41s 136ms/step - loss: 0.5339 - binary_accuracy: 0.7321 - val_loss: 0.5507 - val_binary_accuracy: 0.7166
# Epoch 47/50
# 303/303 [==============================] - 37s 122ms/step - loss: 0.5427 - binary_accuracy: 0.7431 - val_loss: 0.5469 - val_binary_accuracy: 0.7166
# Epoch 48/50
# 303/303 [==============================] - 40s 132ms/step - loss: 0.5502 - binary_accuracy: 0.7266 - val_loss: 0.5473 - val_binary_accuracy: 0.7166
# Epoch 49/50
# 303/303 [==============================] - 38s 126ms/step - loss: 0.5419 - binary_accuracy: 0.7332 - val_loss: 0.5462 - val_binary_accuracy: 0.7193
# Epoch 50/50
# 303/303 [==============================] - 39s 129ms/step - loss: 0.5373 - binary_accuracy: 0.7453 - val_loss: 0.5468 - val_binary_accuracy: 0.7193

# %%
model_file_path = '/content/drive/My Drive/Rays/Projects/Saved_Models/AlexNet.h5'

# Save the model
alex.save(model_file_path)

# %%
#Plot the AlexNet learning curves
plotting(alex_hist, "/content/drive/My Drive/Rays/Images_Graphs/Statistical/AlexNET_50epochs_stats.png", False, 35, 15)
# Out:
# 0.004068630107783256
# 0.003807470055277425
# 0.5510553479194641
# 0.7138273341315133

# %% [markdown]
# #LeNet

# %%
#Instantiate the LeNet Model
lenet = LeNet(img_ch, img_width, img_height)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 224, 224, 4)       40
#
#  max_pooling2d_3 (MaxPooling  (None, 112, 112, 4)      0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 112, 112, 8)       296
#
#  max_pooling2d_4 (MaxPooling  (None, 56, 56, 8)        0
#  2D)
#
#  flatten_2 (Flatten)         (None, 25088)             0
#
#  dense_7 (Dense)             (None, 8)                 200712
#
#  dense_8 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 201,057
# Trainable params: 201,057
# Non-trainable params: 0
# _________________________________________________________________

# %%
lenet.compile(loss='binary_crossentropy',
              optimizer=Adam(learning_rate=learn_rate),
              metrics=['binary_accuracy'])

# %%
#Train the LeNet model
lenet_hist = lenet.fit(x_train, y_train, batch_size = batch_s,
                  validation_data = (x_val, y_val),
                  epochs = n_epochs, verbose=1)
# Out:
# Epoch 1/50
# 303/303 [==============================] - 33s 106ms/step - loss: 0.6913 - binary_accuracy: 0.5733 - val_loss: 0.6844 - val_binary_accuracy: 0.6791
# Epoch 2/50
# 303/303 [==============================] - 27s 89ms/step - loss: 0.6647 - binary_accuracy: 0.6770 - val_loss: 0.6470 - val_binary_accuracy: 0.6791
# Epoch 3/50
# 303/303 [==============================] - 27s 88ms/step - loss: 0.6386 - binary_accuracy: 0.6770 - val_loss: 0.6338 - val_binary_accuracy: 0.6791
# Epoch 4/50
# 303/303 [==============================] - 27s 89ms/step - loss: 0.6303 - binary_accuracy: 0.6770 - val_loss: 0.6295 - val_binary_accuracy: 0.6791
# Epoch 5/50
# 303/303 [==============================] - 30s 99ms/step - loss: 0.6277 - binary_accuracy: 0.6770 - val_loss: 0.6278 - val_binary_accuracy: 0.6791
# Epoch 6/50
# 303/303 [==============================] - 28s 92ms/step - loss: 0.6265 - binary_accuracy: 0.6770 - val_loss: 0.6267 - val_binary_accuracy: 0.6791
# Epoch 7/50
# 303/303 [==============================] - 27s 89ms/step - loss: 0.6255 - binary_accuracy: 0.6770 - val_loss: 0.6254 - val_binary_accuracy: 0.6791
# Epoch 8/50
# 303/303 [==============================] - 29s 95ms/step - loss: 0.6239 - binary_accuracy: 0.6770 - val_loss: 0.6240 - val_binary_accuracy: 0.6791
# Epoch 9/50
# 303/303 [==============================] - 28s 94ms/step - loss: 0.6225 - binary_accuracy: 0.6770 - val_loss: 0.6225 - val_binary_accuracy: 0.6791
# Epoch 10/50
# 303/303 [==============================] - 27s 89ms/step - loss: 0.6211 - binary_accuracy: 0.6770 - val_loss: 0.6211 - val_binary_accuracy: 0.6791
# Epoch 11/50
# 303/303 [==============================] - 27s 90ms/step - loss: 0.6197 - binary_accuracy: 0.6770 - val_loss: 0.6197 - val_binary_accuracy: 0.6791
# Epoch 12/50
# 303/303 [==============================] - 29s 97ms/step - loss: 0.6183 - binary_accuracy: 0.6770 - val_loss: 0.6184 - val_binary_accuracy: 0.6791
# Epoch 13/50
# 303/303 [==============================] - 26s 84ms/step - loss: 0.6167 - binary_accuracy: 0.6770 - val_loss: 0.6168 - val_binary_accuracy: 0.6791
# Epoch 14/50
# 303/303 [==============================] - 27s 90ms/step - loss: 0.6153 - binary_accuracy: 0.6770 - val_loss: 0.6152 - val_binary_accuracy: 0.6791
# Epoch 15/50
# 303/303 [==============================] - 28s 91ms/step - loss: 0.6139 - binary_accuracy: 0.6770 - val_loss: 0.6137 - val_binary_accuracy: 0.6791
# Epoch 16/50
# 303/303 [==============================] - 27s 90ms/step - loss: 0.6121 - binary_accuracy: 0.6770 - val_loss: 0.6121 - val_binary_accuracy: 0.6791
# Epoch 17/50
# 303/303 [==============================] - 27s 88ms/step - loss: 0.6113 - binary_accuracy: 0.6770 - val_loss: 0.6105 - val_binary_accuracy: 0.6791
# Epoch 18/50
# 303/303 [==============================] - 26s 84ms/step - loss: 0.6094 - binary_accuracy: 0.6770 - val_loss: 0.6088 - val_binary_accuracy: 0.6791
# Epoch 19/50
# 303/303 [==============================] - 31s 103ms/step - loss: 0.6085 - binary_accuracy: 0.6770 - val_loss: 0.6073 - val_binary_accuracy: 0.6791
# Epoch 20/50
# 303/303 [==============================] - 27s 90ms/step - loss: 0.6066 - binary_accuracy: 0.6770 - val_loss: 0.6056 - val_binary_accuracy: 0.6791
# Epoch 21/50
# 303/303 [==============================] - 27s 90ms/step - loss: 0.6053 - binary_accuracy: 0.6770 - val_loss: 0.6037 - val_binary_accuracy: 0.6791
# Epoch 22/50
# 303/303 [==============================] - 26s 86ms/step - loss: 0.6033 - binary_accuracy: 0.6770 - val_loss: 0.6019 - val_binary_accuracy: 0.6791
# Epoch 23/50
# 303/303 [==============================] - 28s 92ms/step - loss: 0.6015 - binary_accuracy: 0.6770 - val_loss: 0.6003 - val_binary_accuracy: 0.6791
# Epoch 24/50
# 303/303 [==============================] - 29s 96ms/step - loss: 0.5995 - binary_accuracy: 0.6770 - val_loss: 0.5983 - val_binary_accuracy: 0.6791
# Epoch 25/50
# 303/303 [==============================] - 27s 91ms/step - loss: 0.5985 - binary_accuracy: 0.6770 - val_loss: 0.5961 - val_binary_accuracy: 0.6791
# Epoch 26/50
# 303/303 [==============================] - 30s 98ms/step - loss: 0.5968 - binary_accuracy: 0.6770 - val_loss: 0.5944 - val_binary_accuracy: 0.6791
# Epoch 27/50
# 303/303 [==============================] - 29s 94ms/step - loss: 0.5950 - binary_accuracy: 0.6770 - val_loss: 0.5928 - val_binary_accuracy: 0.6791
# Epoch 28/50
# 303/303 [==============================] - 27s 91ms/step - loss: 0.5935 - binary_accuracy: 0.6792 - val_loss: 0.5907 - val_binary_accuracy: 0.6791
# Epoch 29/50
# 303/303 [==============================] - 28s 92ms/step - loss: 0.5916 - binary_accuracy: 0.6781 - val_loss: 0.5888 - val_binary_accuracy: 0.6791
# Epoch 30/50
# 303/303 [==============================] - 26s 84ms/step - loss: 0.5895 - binary_accuracy: 0.6770 - val_loss: 0.5865 - val_binary_accuracy: 0.6818
# Epoch 31/50
# 303/303 [==============================] - 27s 89ms/step - loss: 0.5879 - binary_accuracy: 0.6792 - val_loss: 0.5850 - val_binary_accuracy: 0.6791
# Epoch 32/50
# 303/303 [==============================] - 29s 95ms/step - loss: 0.5867 - binary_accuracy: 0.6792 - val_loss: 0.5828 - val_binary_accuracy: 0.6845
# Epoch 33/50
# 303/303 [==============================] - 30s 100ms/step - loss: 0.5850 - binary_accuracy: 0.6847 - val_loss: 0.5811 - val_binary_accuracy: 0.6898
# Epoch 34/50
# 303/303 [==============================] - 28s 92ms/step - loss: 0.5833 - binary_accuracy: 0.6847 - val_loss: 0.5794 - val_binary_accuracy: 0.6845
# Epoch 35/50
# 303/303 [==============================] - 32s 105ms/step - loss: 0.5816 - binary_accuracy: 0.6880 - val_loss: 0.5778 - val_binary_accuracy: 0.6872
# Epoch 36/50
# 303/303 [==============================] - 27s 89ms/step - loss: 0.5810 - binary_accuracy: 0.6935 - val_loss: 0.5759 - val_binary_accuracy: 0.6898
# Epoch 37/50
# 303/303 [==============================] - 26s 87ms/step - loss: 0.5782 - binary_accuracy: 0.6968 - val_loss: 0.5747 - val_binary_accuracy: 0.6925
# Epoch 38/50
# 303/303 [==============================] - 25s 84ms/step - loss: 0.5769 - binary_accuracy: 0.6880 - val_loss: 0.5729 - val_binary_accuracy: 0.7112
# Epoch 39/50
# 303/303 [==============================] - 29s 94ms/step - loss: 0.5761 - binary_accuracy: 0.7078 - val_loss: 0.5714 - val_binary_accuracy: 0.7032
# Epoch 40/50
# 303/303 [==============================] - 30s 98ms/step - loss: 0.5745 - binary_accuracy: 0.7001 - val_loss: 0.5698 - val_binary_accuracy: 0.7139
# Epoch 41/50
# 303/303 [==============================] - 29s 95ms/step - loss: 0.5731 - binary_accuracy: 0.7023 - val_loss: 0.5684 - val_binary_accuracy: 0.7219
# Epoch 42/50
# 303/303 [==============================] - 29s 95ms/step - loss: 0.5713 - binary_accuracy: 0.7100 - val_loss: 0.5674 - val_binary_accuracy: 0.7112
# Epoch 43/50
# 303/303 [==============================] - 27s 89ms/step - loss: 0.5704 - binary_accuracy: 0.7189 - val_loss: 0.5659 - val_binary_accuracy: 0.7193
# Epoch 44/50
# 303/303 [==============================] - 27s 91ms/step - loss: 0.5692 - binary_accuracy: 0.7133 - val_loss: 0.5646 - val_binary_accuracy: 0.7166
# Epoch 45/50
# 303/303 [==============================] - 27s 90ms/step - loss: 0.5677 - binary_accuracy: 0.7155 - val_loss: 0.5635 - val_binary_accuracy: 0.7139
# Epoch 46/50
# 303/303 [==============================] - 27s 88ms/step - loss: 0.5667 - binary_accuracy: 0.7222 - val_loss: 0.5622 - val_binary_accuracy: 0.7086
# Epoch 47/50
# 303/303 [==============================] - 29s 95ms/step - loss: 0.5653 - binary_accuracy: 0.7222 - val_loss: 0.5614 - val_binary_accuracy: 0.7139
# Epoch 48/50
# 303/303 [==============================] - 27s 90ms/step - loss: 0.5644 - binary_accuracy: 0.7255 - val_loss: 0.5604 - val_binary_accuracy: 0.7139
# Epoch 49/50
# 303/303 [==============================] - 27s 90ms/step - loss: 0.5633 - binary_accuracy: 0.7321 - val_loss: 0.5592 - val_binary_accuracy: 0.7112
# Epoch 50/50
# 303/303 [==============================] - 25s 83ms/step - loss: 0.5628 - binary_accuracy: 0.7233 - val_loss: 0.5580 - val_binary_accuracy: 0.7166

# %%
model_file_path = '/content/drive/My Drive/Rays/Projects/Saved_Models/LeNet.h5'

# Save the model
lenet.save(model_file_path)

# %%
#Plot the LeNet learning curves
plotting(lenet_hist, "/content/drive/My Drive/Rays/Images_Graphs/Statistical/LeNET_50epochs_stats.png", False, 40,45)
# Out:
# 0.0032964087639748814
# 0.00272673782628227
# 0.5631074607372284
# 0.7128342151641845
